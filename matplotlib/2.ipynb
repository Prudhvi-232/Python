# %%
import matplotlib.pyplot as plt   
# %matplotlib inline

# %%
x = [1,2,3,4,5,6,7]
y=[50,54,23,45,67,28,76]

# %%
plt.xlabel('day')
plt.ylabel('temp')
plt.title('weather')
plt.plot(x,y)

# %%
plt.plot(x,y,color='blue',marker='+',linestyle='',alpha=0.5)
